# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhigna810/AIAC/blob/main/M_SAI_ABHIGNA_2403A51014_BATCH_1_ML_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/Salary_dataset.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
X = data[['YearsExperience']]

# %%
y = data[['Salary']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-276855866.py in <cell line: 0>()
# ----> 1 y = data[['Salary']]
#
# NameError: name 'data' is not defined
